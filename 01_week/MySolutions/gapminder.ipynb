# %%
import pandas as pd


PATH="../../garlic-boosting-encounter-notes/01_week/data/"


df_life_expecancy = pd.read_excel(PATH + "gapminder_lifeexpectancy.xlsx")

df_population     = pd.read_excel(PATH + "gapminder_population.xlsx")

df_fertility      = pd.read_csv(PATH + "gapminder_total_fertility.csv")

df_continents     = pd.read_csv(PATH + "continents.csv", sep=";")

# %%
df_population.head()
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...        2006  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...  25183615.0
# 2        NaN        NaN        NaN        NaN        NaN  ...     15700.0
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...   3050741.0
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...  33749328.0
#
#          2007        2008        2009        2010        2011        2012  \
# ...

# %%
df_continents.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %% [markdown]
# Check the shape

# %%
print("fertility:", df_fertility.shape)
print("population:", df_population.shape)
print("life expectancy:", df_life_expecancy.shape)
# Out:
# fertility: (260, 217)
# population: (275, 82)
# life expectancy: (260, 218)

# %% [markdown]
# check the clumn names - Step 4

# %%
df_fertility.columns
# Out:
# Index(['Total fertility rate', '1800', '1801', '1802', '1803', '1804', '1805',
#        '1806', '1807', '1808',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=217)

# %%
df_life_expecancy.columns
# Out:
# Index(['Life expectancy',              1800,              1801,
#                     1802,              1803,              1804,
#                     1805,              1806,              1807,
#                     1808,
#        ...
#                     2007,              2008,              2009,
#                     2010,              2011,              2012,
#                     2013,              2014,              2015,
#                     2016],
#       dtype='object', length=218)

# %%
df_population.columns
# Out:
# Index(['Total population',               1800,               1810,
#                      1820,               1830,               1840,
#                      1850,               1860,               1870,
#                      1880,               1890,               1900,
#                      1910,               1920,               1930,
#                      1940,               1950,               1951,
#                      1952,               1953,               1954,
#                      1955,               1956,               1957,
#                      1958,               1959,               1960,
#                      1961,               1962,               1963,
#                      1964,               1965,               1966,
#                      1967,               1968,               1969,
#                      1970,               1971,               1972,
#                      1973,               1974,               1975,
# ...

# %% [markdown]
# Step 5

# %% [markdown]
# set index

# %%
#df_fertility.set_index(df_fertility.iloc[:,0], inplace=True)
df_fertility.set_index(df_fertility.columns[0], inplace=True)
df_population.set_index(df_population.columns[0], inplace=True)
df_life_expecancy.set_index(df_life_expecancy.columns[0], inplace=True)

# %%
df_fertility.index.name="countries"
df_population.index.name="countries"
df_life_expecancy.index.name="countries"

# %%
df_fertility.columns=df_fertility.columns.astype(int)

# %%
df_fertility.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# countries
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# countries                    ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
df_life_expecancy.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# countries
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# countries                            ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %%
df_population.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# countries
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# countries
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %% [markdown]
# ## Step 6

# %% [markdown]
# ### Turning wide into long

# %%
for df in [df_fertility, df_population,df_life_expecancy]:
    df.reset_index(inplace=True)

# %%
df_fertility_long=df_fertility.melt(id_vars="countries", var_name="years", value_name="fertility_rates")

# %% [markdown]
# the opposite of melt is pivot_table:

# %%
df_fertility_long.pivot_table(columns="years", index="countries", dropna=False)
# Out:
#                       fertility_rates                                      \
# years                            1800  1801  1802  1803  1804  1805  1806
# countries
# Abkhazia                          NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan                      7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia             NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                          4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                          6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                               ...   ...   ...   ...   ...   ...   ...
# Yemen                            6.88  6.88  6.88  6.88  6.88  6.88  6.88
# Yugoslavia                        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                           6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe                         6.75  6.75  6.75  6.75  6.75  6.75  6.75
# ...

# %%
df_fertility_long.head()
# Out:
#                countries years  fertility_rates
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800             7.00
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800             4.60
# 4                Algeria  1800             6.99

# %%
df_life_expecancy_long=df_life_expecancy.melt(id_vars="countries", var_name="years", value_name="life_expectancies")

# %%
df_population_long=df_population.melt(id_vars="countries", var_name="years", value_name="population")

# %%
df_continents.rename({"country":"countries"}, axis=1, inplace=True)

# %% [markdown]
# #### Step 9

# %% [markdown]
# "concat" is only concatenating the tables

# %%
pd.concat([df_fertility_long, df_life_expecancy_long])
# Out:
#                    countries years  fertility_rates  life_expectancies
# 0                   Abkhazia  1800              NaN                NaN
# 1                Afghanistan  1800             7.00                NaN
# 2      Akrotiri and Dhekelia  1800              NaN                NaN
# 3                    Albania  1800             4.60                NaN
# 4                    Algeria  1800             6.99                NaN
# ...                      ...   ...              ...                ...
# 56415             Yugoslavia  2016              NaN                NaN
# 56416                 Zambia  2016              NaN              57.10
# 56417               Zimbabwe  2016              NaN              61.69
# 56418                  Åland  2016              NaN                NaN
# 56419            South Sudan  2016              NaN              56.10
#
# [112580 rows x 4 columns]

# %% [markdown]
# "join"  is only taking into account 'index'

# %%
df_fertility_long.join(df_life_expecancy_long, lsuffix="_fert", rsuffix="_life")
# Out:
#               countries_fert years_fert  fertility_rates  \
# 0                   Abkhazia       1800              NaN
# 1                Afghanistan       1800             7.00
# 2      Akrotiri and Dhekelia       1800              NaN
# 3                    Albania       1800             4.60
# 4                    Algeria       1800             6.99
# ...                      ...        ...              ...
# 56155             Yugoslavia       2015              NaN
# 56156                 Zambia       2015             5.59
# 56157               Zimbabwe       2015             3.35
# 56158                  Åland       2015              NaN
# 56159                  Åland       2015              NaN
#
#               countries_life years_life  life_expectancies
# 0                   Abkhazia       1800                NaN
# 1                Afghanistan       1800              28.21
# 2      Akrotiri and Dhekelia       1800                NaN
# ...

# %% [markdown]
# 'merge' is the way to go because

# %%
df_gapminder=df_fertility_long.merge(df_life_expecancy_long, on= ["countries", "years"])

# %%
df_gapminder=df_gapminder.merge(df_population_long, on= ["countries", "years"])

# %%
df_gapminder
# Out:
#                    countries years  fertility_rates  life_expectancies  \
# 0                   Abkhazia  1800              NaN                NaN
# 1                Afghanistan  1800             7.00              28.21
# 2      Akrotiri and Dhekelia  1800              NaN                NaN
# 3                    Albania  1800             4.60              35.40
# 4                    Algeria  1800             6.99              28.82
# ...                      ...   ...              ...                ...
# 20974             Yugoslavia  2015              NaN                NaN
# 20975                 Zambia  2015             5.59              56.70
# 20976               Zimbabwe  2015             3.35              59.30
# 20977                  Åland  2015              NaN                NaN
# 20978                  Åland  2015              NaN                NaN
#
#        population
# 0             NaN
# 1       3280000.0
# 2             NaN
# 3        410445.0
# ...

# %%
df_continents
# Out:
#          continent  countries
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
df_gapminder=df_gapminder.merge(df_continents, on= ["countries"], how="left")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_gapminder_2000 = df_gapminder.loc[df_gapminder['years'] == 2000]
#sns.scatterplot(x='life expectancies', y='fertility rates', hue='continent',
#            size='population', data=df_gapminder_2000, alpha=0.6)
#plt.legend(loc=2, bbox_to_anchor=(1, 1))

# %%
df_gapminder_2000
# Out:
#                    countries years  fertility_rates  life_expectancies  \
# 16835               Abkhazia  2000              NaN                NaN
# 16836            Afghanistan  2000             7.73               50.1
# 16837  Akrotiri and Dhekelia  2000              NaN                NaN
# 16838                Albania  2000             2.38               74.7
# 16839                Algeria  2000             2.51               73.3
# ...                      ...   ...              ...                ...
# 17089             Yugoslavia  2000              NaN                NaN
# 17090                 Zambia  2000             6.07               44.8
# 17091               Zimbabwe  2000             4.07               47.9
# 17092                  Åland  2000              NaN               80.0
# 17093                  Åland  2000              NaN               80.0
#
#        population continent
# 16835         NaN       NaN
# 16836  19701940.0      Asia
# ...

# %%
sns.scatterplot(x='life_expectancies', y='fertility_rates', data=df_gapminder_2000, alpha=0.6, hue="continent")
# Out:
# <AxesSubplot:xlabel='life_expectancies', ylabel='fertility_rates'>

# %%
popmax=df_gapminder["population"].max()
lifemax=df_gapminder["life_expectancies"].max()
fertmax=df_gapminder["fertility_rates"].max()
popmin=df_gapminder["population"].min()
lifemin=df_gapminder["life_expectancies"].min()
fertmin=df_gapminder["fertility_rates"].min()

# %%
popmax/1000000
# Out:
# 1376.048943

# %%
df_gapminder_2000["population"].max()
# Out:
# 1269974572.0

# %%
allyears=df_gapminder["years"].unique()

# %%
import numpy as np

# %%
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(111)

for year in [1810,2010,]:
    yearstr=str(year)
    print(yearstr)
    
    df_gapminder_tmp = df_gapminder.loc[df_gapminder['years'] == year]

    sns.scatterplot(x='life_expectancies', y='fertility_rates', hue='continent',
            size='population',size_norm=(popmin,popmax), data=df_gapminder_tmp, alpha=0.6, ax=ax)
    
    ax.set_xlim(lifemin-lifemin*0.05,lifemax+lifemax*0.05)
    ax.set_ylim(fertmin-fertmin*0.05,fertmax+fertmax*0.05)
    
    
    plt.legend(loc=2, bbox_to_anchor=(1, 1))
    

allhandels,alllabels=ax.get_legend_handles_labels()
# Out:
# 1810
# 2010

# %%
for i,year in enumerate(allyears):
    fig=plt.figure(figsize=(8,5))
    ax=fig.add_subplot(111)
    yearstr=str(year)
    if i%10==0: print(yearstr)
    df_gapminder_tmp = df_gapminder.loc[df_gapminder['years'] == year]

    sns.scatterplot(x='life_expectancies', y='fertility_rates', hue='continent',
            size='population',size_norm=(popmin,popmax), data=df_gapminder_tmp, alpha=0.6, ax=ax)
    
    ax.set_xlim(lifemin-lifemin*0.05,lifemax+lifemax*0.05)
    ax.set_ylim(fertmin-fertmin*0.05,fertmax+fertmax*0.05)
    
    handels,labels=ax.get_legend_handles_labels()
    plt.legend(handels[0:7],labels[0:7],loc=2, bbox_to_anchor=(1, 1))
    #plt.legend(handels,labels,loc=2, bbox_to_anchor=(1, 1))
    plt.title(yearstr)
    plt.tight_layout()
    plt.savefig(yearstr+"_gapminder.png", dpi=150)
    #plt.show()
    plt.clf()
    plt.close();
# Out:
# 1800
# 1900
# 1955
# 1965
# 1975
# 1985
# 1995
# 2005
# 2015

# %%
import imageio.v2 as io

# %%
#!convert -delay 10 -loop 0 ????_gap*png myAnimation.gif

# %%
import glob

# %%
imagefiles=sorted(glob.glob("*_gap*.png"))

# %%
images=[]
for imfile in imagefiles:
    images.append(io.imread(imfile))

# %%
io.mimsave("output.gif", images, fps=20)
