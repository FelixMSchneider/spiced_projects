# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df1=pd.read_excel("../../garlic-boosting-encounter-notes/01_week/data/gapminder_lifeexpectancy.xlsx")

df2=pd.read_excel("../../garlic-boosting-encounter-notes/01_week/data/gapminder_population.xlsx")

df3=pd.read_csv("../../garlic-boosting-encounter-notes/01_week/data/gapminder_total_fertility.csv")

# %%
df1.head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
df2.head()
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...        2006  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...  25183615.0
# 2        NaN        NaN        NaN        NaN        NaN  ...     15700.0
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...   3050741.0
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...  33749328.0
#
#          2007        2008        2009        2010        2011        2012  \
# ...

# %%
df3.head()
# Out:
#     Total fertility rate  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0               Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2  Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#    1808  ...  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# 2   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
# 4  6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82  2.80  2.76  2.71
#
# [5 rows x 217 columns]

# %%
fig,ax=plt.subplots()

ax=df1[2000].hist()
ax.set_xlim(0,100)
ax.set_xlabel("Life expectancy [years]")
ax.set_ylabel("number of countries")

plt.savefig('histo.png')

# %%
year=2000
for bin in [5,10,20]:
    fig,ax=plt.subplots()

    ax=df1[year].hist(bins=bin)
    #ax.set_xlim(0,100)
    #ax.set_ylim(0,80)
    plt.axis([0.0, 100.0, 0.0, 80.0])
    ax.set_xlabel("Life expectancy [years]")
    ax.set_ylabel("number of countries")

    
    plt.title('Life Expendency in '+str(year)+' using Bins of '+str(bin)+' years')
    plt.savefig('histo_bins_'+str(bin)+'.png')

# %%
a=df1[2000]

# %%
fig,ax=plt.subplots()
a.hist(histtype="bar", alpha=1, facecolor='#00ff00')
a.hist(histtype="step", alpha=1, color='#000000', linewidth=4)
ax.set_xlabel("Life expectancy [years]")

plt.savefig("histo_green.png", dpi=150)

# %%
plt.scatter(df1[1800],df1[2000])
plt.xlabel("life expectancy in year 1800")
plt.ylabel("life expectancy in year 2000");

# %%
plt.scatter(df1[2000],df3['2000'])
plt.xlabel("life exectancy")
plt.ylabel("fertility rate")
# Out:
# Text(0, 0.5, 'fertility rate')

# %%
type(df1[2000])
# Out:
# pandas.core.series.Series

# %%
plt.scatter?

# %%
df1[2000].index
# Out:
# RangeIndex(start=0, stop=260, step=1)

# %%
df1[2000].to_numpy()
# Out:
# array([  nan, 50.1 ,   nan, 74.7 , 73.3 , 71.7 , 83.7 , 52.3 ,   nan,
#        73.8 , 74.2 , 71.3 , 73.78, 79.8 , 78.2 , 66.5 , 70.2 , 73.7 ,
#        64.9 , 74.  , 68.1 , 77.8 , 69.  , 57.2 , 74.1 , 65.9 , 67.6 ,
#        75.7 , 47.6 , 70.7 ,   nan, 75.9 , 71.6 , 52.6 , 46.7 , 60.  ,
#        54.3 , 79.2 , 68.4 ,   nan, 45.3 , 51.5 , 77.61, 77.3 , 69.8 ,
#          nan,   nan, 73.3 , 62.1 , 54.3 , 52.5 ,   nan, 77.7 , 52.  ,
#        74.2 , 76.2 , 77.7 , 75.  ,   nan, 77.1 , 60.  , 73.7 , 73.3 ,
#          nan, 73.2 , 69.7 , 71.9 , 52.9 , 37.6 ,   nan, 70.4 , 52.1 ,
#          nan,   nan, 64.2 , 77.8 , 79.1 , 74.75, 72.31, 59.3 , 63.6 ,
#        71.4 , 78.1 , 60.  ,   nan, 78.6 , 67.8 , 70.5 , 77.12, 73.6 ,
#        68.8 ,   nan, 54.2 , 52.8 , 64.2 , 58.7 ,   nan, 70.5 , 80.36,
#        71.8 , 80.5 , 61.5 , 67.5 , 71.4 , 65.8 , 77.8 ,   nan, 78.6 ,
#        79.6 , 74.4 , 81.  ,   nan, 73.4 , 64.9 , 55.6 , 59.8 , 59.1 ,
# ...

# %%
df1.set_index(df1.iloc[:,0],inplace=True)

# %%
df1
# Out:
#                              Life expectancy   1800   1801   1802   1803  \
# Life expectancy
# Abkhazia                            Abkhazia    NaN    NaN    NaN    NaN
# Afghanistan                      Afghanistan  28.21  28.20  28.19  28.18
# Akrotiri and Dhekelia  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN
# Albania                              Albania  35.40  35.40  35.40  35.40
# Algeria                              Algeria  28.82  28.82  28.82  28.82
# ...                                      ...    ...    ...    ...    ...
# Yugoslavia                        Yugoslavia    NaN    NaN    NaN    NaN
# Zambia                                Zambia  32.60  32.60  32.60  32.60
# Zimbabwe                            Zimbabwe  33.70  33.70  33.70  33.70
# Åland                                  Åland    NaN    NaN    NaN    NaN
# South Sudan                      South Sudan  26.67  26.67  26.67  26.67
#
# ...

# %%
plt.scatter(df1[1800], df1[2000])

# %%
df1[1800]
# Out:
# Life expectancy
# Abkhazia                   NaN
# Afghanistan              28.21
# Akrotiri and Dhekelia      NaN
# Albania                  35.40
# Algeria                  28.82
#                          ...
# Yugoslavia                 NaN
# Zambia                   32.60
# Zimbabwe                 33.70
# Åland                      NaN
# South Sudan              26.67
# Name: 1800, Length: 260, dtype: float64

# %%
a=np.arange(10)

# %%
a.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 a.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
for i in df1[1800].index:
    print(i)
# Out:
# Abkhazia
# Afghanistan
# Akrotiri and Dhekelia
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Brazil
# British Virgin Islands
# Brunei
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Channel Islands
# Chile
# China
# Christmas Island
# Cocos Island
# Colombia
# Comoros
# Congo, Dem. Rep.
# Congo, Rep.
# Cook Is
# Costa Rica
# Cote d'Ivoire
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Czechoslovakia
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# East Germany
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Eritrea and Ethiopia
# Estonia
# Ethiopia
# Faeroe Islands
# Falkland Is (Malvinas)
# Fiji
# Finland
# France
# ...

# %%
df1=pd.read_excel("../../garlic-boosting-encounter-notes/01_week/data/gapminder_lifeexpectancy.xlsx", index_col=0)

# %%
df1
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
df3=pd.read_csv("../../garlic-boosting-encounter-notes/01_week/data/gapminder_total_fertility.csv", index_col=0)

# %%
df3.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
df_=pd.read_excel("../../garlic-boosting-encounter-notes/01_week/data/gapminder_lifeexpectancy.xlsx")

# %%
df_.set_index(['Life expectancy'])
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
df_.head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
df3[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/NewSpiced/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniconda3/envs/NewSpiced/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/NewSpiced/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ...
